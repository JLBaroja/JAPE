# %%
Wr <- 0:20
Wl <- 0:20
ratioW <- array(dim=c(length(Wr),length(Wl)))
for(i in 1:length(Wr)){
    for(j in 1:length(Wl)){
        ratioW[i,j] <- Wr[i]/Wl[j]
    }
}
persp(x = Wl,y = Wr,z = ratioW,zlim=c(0,20),ticktype = 'detailed',col='#0044ee77',theta=-130,phi=5)
# summary(ratioW,na.rm=T)
# Out:
# Warning message in persp.default(x = Wl, y = Wr, z = ratioW, zlim = c(0, 20), ticktype = "detailed", :
# “surface extends beyond the box”
# plot without title
