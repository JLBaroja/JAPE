# %%
bb_responses <- read.csv('~/ResearchProjects/JAPE/ConcurrentData/ResponseAnalysis/responses_p530.csv')

# %%
dim(bb_responses)
# Out:
# [1] 397532     15

# %%
bb_ss_responses <- subset(bb_responses,session=='s19')

# %%
dim(bb_ss_responses)
# Out:
# [1] 2832   15

# %%
head(bb_ss_responses,60)
# Out:
#        lever time   irt_local irt_global reinforced session bird cum_resp_left
# 255905 right   1.99  0.00      0.00      FALSE      s116    p054  0
# 255906 left    4.13  0.00      2.14      FALSE      s116    p054  1
# 255907 left    4.55  0.42      0.42      FALSE      s116    p054  2
# 255908 left    4.97  0.42      0.42      FALSE      s116    p054  3
# 255909 left    7.68  2.71      2.71      FALSE      s116    p054  4
# 255910 right  19.79 17.80     12.11       TRUE      s116    p054  4
# 255911 left   24.17 16.49      4.38      FALSE      s116    p054  5
# 255912 right  28.10  8.31      3.93      FALSE      s116    p054  5
# 255913 right  29.20  1.10      1.10      FALSE      s116    p054  5
# 255914 left   31.77  7.60      2.57      FALSE      s116    p054  6
# 255915 right  35.31  6.11      3.54      FALSE      s116    p054  6
# 255916 right  35.69  0.38      0.38      FALSE      s116    p054  6
# 255917 left   37.79  6.02      2.10      FALSE      s116    p054  7
# ...

# %%
irt <- bb_ss_responses$irt_global
irt <- irt*(-2*as.numeric(bb_ss_responses$lever=='left')+1)

options(repr.plot.width=15)
hist(irt,breaks=400,xlim=c(-5,5));abline(v=0,col='red')
# Out:
# Plot with title “Histogram of irt”

# %%
data.frame(bb_ss_responses$irt_global,irt,bb_ss_responses$lever)
# Out:
#      bb_ss_responses.irt_global irt   bb_ss_responses.lever
# 1    0.00                        0.00 left
# 2    0.54                       -0.54 left
# 3    0.04                       -0.04 left
# 4    0.52                       -0.52 left
# 5    0.70                       -0.70 left
# 6    0.61                       -0.61 left
# 7    0.77                       -0.77 left
# 8    0.08                       -0.08 left
# 9    0.67                       -0.67 left
# 10   0.07                       -0.07 left
# 11   1.77                        1.77 right
# 12   1.74                       -1.74 left
# 13   0.92                       -0.92 left
# 14   0.77                       -0.77 left
# 15   0.94                        0.94 right
# 16   0.08                        0.08 right
# 17   0.91                       -0.91 left
# 18   4.06                       -4.06 left
# 19   0.04                       -0.04 left
# 20   0.76                       -0.76 left
# ...
